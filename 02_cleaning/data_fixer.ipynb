# %%
import numpy as np
import pandas as pd
import os
                                
base_url = os.path.expanduser('~/Documents/Data Science/Data Projects/Capstone 1/data/ncaa')
# base_url = os.path.expanduser('~/Desktop/new_college_data')

# %matplotlib inline

# %%
db = ['CB', 'DB', 'SS', 'FS', 'S']

# %% [markdown]
# ## Players

# %%
# import players
p05 = pd.read_csv(base_url + '/players-2005.csv')
p06 = pd.read_csv(base_url + '/players-2006.csv')
p07 = pd.read_csv(base_url + '/players-2007.csv')
p08 = pd.read_csv(base_url + '/players-2008.csv')
p09 = pd.read_csv(base_url + '/players-2009.csv')
p10 = pd.read_csv(base_url + '/players-2010.csv')
p11 = pd.read_csv(base_url + '/players-2011.csv')
p12 = pd.read_csv(base_url + '/players-2012.csv')
p13 = pd.read_csv(base_url + '/players-2013.csv')
all = pd.concat([p05, p06, p07, p08, p09, p10, p11, p12, p13], sort=False)
all.info()

dbs = all[all.Position.isin(db)]
dbs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182237 entries, 0 to 21792
# Data columns (total 13 columns):
# Player Code       182237 non-null int64
# Team Code         182237 non-null float64
# Last Name         182237 non-null object
# First Name        181394 non-null object
# Uniform Number    178907 non-null object
# Class             178443 non-null object
# Position          178661 non-null object
# Height            90828 non-null float64
# Weight            90742 non-null float64
# Home Town         90773 non-null object
# Home State        90456 non-null object
# Home Country      90778 non-null object
# Last School       87551 non-null object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 19.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30663 entries, 3 to 21792
# Data columns (total 13 columns):
# Player Code       30663 non-null int64
# Team Code         30663 non-null float64
# Last Name         30663 non-null object
# ...

# %%
# d_backs = all[all['Position'].isin(db)]

# d_backs['name'] = d_backs.loc[:, ['First Name', 'Last Name']].apply(lambda x:' '.join(x), axis=1)

# %% [markdown]
# ## Add Player

# %%
# p_new = {'Player Code':69096, 'Team Code' : 283, 'Last Name' : 'Arrington', 'First Name' : 'Kyle', 'Class' : 'JR', 'Uniform Number' : 20,
#         'Position' : 'CB', 'Height' : 70, 'Weight' : 190, 'Home State' : 'MD'}
# p06 = p06.append(p_new, ignore_index=True)

# p06.tail()
# p06.to_csv(base_url + '/players-2006.csv', index=False )
# Out:
#        Player Code  Team Code  Last Name First Name Uniform Number Class  \
# 17745        77149     2915.0      Young     Adrian              6    JR
# 17746        77150     2915.0      Young       Ryan             95    SO
# 17747        79074      493.0       Dahl      Craig             20    SR
# 17748      1005858      441.0   Anderson       Colt             19    SO
# 17749        69096      283.0  Arrington       Kyle             20    JR
#
#       Position  Height  Weight  Home Town Home State  Home Country  \
# 17745       RB     NaN     NaN        NaN        NaN           NaN
# 17746       DE     NaN     NaN        NaN        NaN           NaN
# 17747        S     NaN     NaN        NaN         MN           NaN
# 17748        S     NaN     NaN        NaN         MT           NaN
# 17749       CB    70.0   190.0        NaN         MD           NaN
#
#        Last School
# 17745          NaN
# 17746          NaN
# 17747          NaN
# 17748          NaN
# 17749          NaN

# %%
# p06.drop(p06.index[17748], inplace=True)

# %%
# p06.to_csv(base_url + '/players-2006.csv', index=False )

# %% [markdown]
# ## Find Player by Code

# %%
player_code = 1027262

print('2005')
p05[p05['Player Code'] == player_code]

print('2006')
p06[p06['Player Code'] == player_code]

print('2007')
p07[p07['Player Code'] == player_code]

print('2008')
p08[p08['Player Code'] == player_code]

print('2009')
p09[p09['Player Code'] == player_code]

print('2010')
p10[p10['Player Code'] == player_code]

print('2011')
p11[p11['Player Code'] == player_code]

print('2012')
p12[p12['Player Code'] == player_code]

print('2013')
p13[p13['Player Code'] == player_code]
# Out:
# 2005
# Empty DataFrame
# Columns: [Player Code, Team Code, Last Name, First Name, Uniform Number, Class, Position, Height, Weight, Home Town, Home State, Home Country, Last School]
# Index: []
# 2006
# Empty DataFrame
# Columns: [Player Code, Team Code, Last Name, First Name, Uniform Number, Class, Position, Height, Weight, Home Town, Home State, Home Country, Last School]
# Index: []
# 2007
# Empty DataFrame
# Columns: [Player Code, Team Code, Last Name, First Name, Uniform Number, Class, Position, Height, Weight, Home Town, Home State, Home Country, Last School]
# Index: []
# 2008
# Empty DataFrame
# Columns: [Player Code, Team Code, Last Name, First Name, Uniform Number, Class, Position, Height, Weight, Home Town, Home State, Home Country, Last School]
# Index: []
# 2009
#        Player Code  Team Code Last Name First Name Uniform Number Class  \
# 13231      1027262         17  Thompson    Brandon             43    FR
#
# ...

# %%
p09.iloc[16489,0] = 1043579

# %% [markdown]
# ## Find Player by Name

# %%
df = dbs
last_name = 'Torrence'

pl = df[df['Last Name'] == last_name]
pl = pl.sort_values(by=['First Name', 'Team Code'])
pl.tail(100)
# Out:
#        Player Code  Team Code Last Name First Name Uniform Number Class  \
# 7670       1010457      518.0  Torrence      Devon             10    FR
# 7948       1010457      518.0  Torrence      Devon              1    SR
# 14718      1005652      355.0  Torrence        Tim             27    SO
# 15610      1027803      355.0  Torrence        Tim             27    SR
#
#       Position  Height  Weight Home Town Home State Home Country   Last School
# 7670         S    73.0   190.0    Canton         OH           US  Canton South
# 7948        DB    73.0   200.0    Canton         OH           US  Canton South
# 14718       DB     NaN     NaN       NaN        NaN          NaN           NaN
# 15610       DB     NaN     NaN       NaN        NaN          NaN           NaN

# %% [markdown]
# ## Find All Players by School

# %%
# a = all[all['Team Code'] == 441]
# a
# Out:
#        Player Code  Team Code        Last Name First Name Uniform Number  \
# 17462        84751      441.0            Allen        NaN              5
# 17463        84758      441.0         Anderson        NaN             19
# 17464        86050      441.0           Bagley        NaN              3
# 17465        87227      441.0           Balogh        NaN             71
# 17466        84756      441.0        Bergquist        NaN             14
# 17467        84767      441.0          Bierman        NaN             53
# 17468        87175      441.0  Brooks-Fletcher        NaN             24
# 17469        87019      441.0        Brunnelle        NaN             45
# 17470        58177      441.0           Cahill       Paul             80
# 17471        73239      441.0          Carlson      Brian             97
# 17472        84760      441.0        Carpenter        NaN             29
# 17473        58178      441.0             Carr        Dan             94
# ...

# %%
# a = df.iloc[, ] = 
# a

# %%
# p05.to_csv(base_url + '/players-2005.csv', index=False )

# %% [markdown]
# ## Fix Player at Index

# %%
a = p05[p05['Last Name'] == 'Ventrone']
a
# Out:
#       Player Code  Team Code Last Name First Name Uniform Number Class  \
# 7974        76763        545  Ventrone       Ross             4A    FR
#
#      Position  Height  Weight  Home Town Home State  Home Country  Last School
# 7974       DB     NaN     NaN        NaN        NaN           NaN          NaN

# %%
# p05.iloc[1108, 6] = 'DB'

# %% [markdown]
# ## Drop Player at Index

# %%
# df = p11
# idx = 16293
# idx_range = range((idx-5), (idx+5))

# h = df.iloc[idx_range, :]
# h

# %%
# df.drop(df.index[idx], inplace=True)

# %%
# p11.to_csv(base_url + '/players-2011.csv', index=False )

# %% [markdown]
# # SAVE ALL

# %%
# p05.to_csv(base_url + '/players-2005.csv', index=False )
# p06.to_csv(base_url + '/players-2006.csv', index=False )
# p07.to_csv(base_url + '/players-2007.csv', index=False )
# p08.to_csv(base_url + '/players-2008.csv', index=False )
# p09.to_csv(base_url + '/players-2009.csv', index=False )
# p10.to_csv(base_url + '/players-2010.csv', index=False )
# p11.to_csv(base_url + '/players-2011.csv', index=False )
# p12.to_csv(base_url + '/players-2012.csv', index=False )
# p13.to_csv(base_url + '/players-2013.csv', index=False )

# %%
teams = pd.read_csv(base_url + '/teams.csv')

a = teams[teams['Team Code'] == 235]
a

teams.head(20)
# Out:
#     Team Code     Name  Conference Code
# 31        235  Florida              911
#     Team Code              Name  Conference Code
# 0           5             Akron              875
# 1           8           Alabama              911
# 2           9               UAB            24312
# 3          28     Arizona State              905
# 4          29           Arizona              905
# 5          30    Arkansas State              818
# 6          31          Arkansas              911
# 7          37            Auburn              911
# 8          47        Ball State              875
# 9          51            Baylor            25354
# 10         66       Boise State             5486
# 11         67    Boston College              821
# 12         71     Bowling Green              875
# 13         77               BYU            99001
# 14         86           Buffalo              875
# 15         96      Fresno State             5486
# ...
